# %%
import pandas as pd
import os
import glob

video_directory = '01_Raw_videos'
adult_directory = '02_Adult_Model'
output_directory = 'h5_to_csv_output'
file_location = os.path.join(video_directory, '*.mp4')

# create list of filenames for every video to be processed
# this list is the input for the video processing function
filenames = glob.glob(file_location)
videoname = []
for f in filenames:
    # establish name for output file from the input filename
    x = os.path.split(f)
    x = x[1].split('.mp4')
    x = x[0]
    videoname.append(x)
videoname

for x in videoname:
    
    # Load in the adult dataframe with points for adult, infants, and nest coordinates
    hdf_file = os.path.join(adult_directory, x)
    hdf_var = glob.glob(hdf_file + '*')
    Adult = pd.read_hdf(hdf_var[0])
    pd.set_option('display.max_columns', 1000)
    
    #Save output to HDf5
    csvFile = (x + "." +'csv')
    csvFile = os.path.join(output_directory, csvFile)
    Adult.to_csv(csvFile, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-fb1cc91848e4> in <module>
#      25     hdf_file = os.path.join(adult_directory, x)
#      26     hdf_var = glob.glob(hdf_file + '*')
# ---> 27     Adult = pd.read_hdf(hdf_var[0])
#      28     pd.set_option('display.max_columns', 1000)
#      29
#
# ~\anaconda3\lib\site-packages\pandas\io\pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     395             raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     396
# --> 397         store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     398         # can't auto open/close if we are using an iterator
#     399         # so delegate to the iterator
#
# ~\anaconda3\lib\site-packages\pandas\io\pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     516             raise ValueError("format is not a defined argument for HDFStore")
#     517
# --> 518         tables = import_optional_dependency("tables")
#     519
#     520         if complib is not None and complib not in tables.filters.all_complibs:
#
# ~\anaconda3\lib\site-packages\pandas\compat\_optional.py in import_optional_dependency(name, extra, raise_on_missing, on_version)
#      87     )
#      88     try:
# ---> 89         module = importlib.import_module(name)
#      90     except ImportError:
#      91         if raise_on_missing:
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\anaconda3\lib\site-packages\tables\__init__.py in <module>
#      71 from .unimplemented import UnImplemented, Unknown
#      72 from .expression import Expr
# ---> 73 from .tests import print_versions, test
#      74
#      75
#
# ~\anaconda3\lib\site-packages\tables\tests\__init__.py in <module>
#      19 """
#      20
# ---> 21 from tables.tests.common import print_versions
#      22 from tables.tests.test_suite import test, suite
#
# ~\anaconda3\lib\site-packages\tables\tests\common.py in <module>
#      23 from distutils.version import LooseVersion
#      24
# ---> 25 from pkg_resources import resource_filename
#      26
#      27 import unittest
#
# ~\anaconda3\lib\site-packages\pkg_resources\__init__.py in <module>
#      81 __import__('pkg_resources.extern.packaging.version')
#      82 __import__('pkg_resources.extern.packaging.specifiers')
# ---> 83 __import__('pkg_resources.extern.packaging.requirements')
#      84 __import__('pkg_resources.extern.packaging.markers')
#      85
#
# ~\anaconda3\lib\site-packages\pkg_resources\_vendor\packaging\requirements.py in <module>
#      53 )("_raw_spec")
#      54 _VERSION_SPEC = Optional(((LPAREN + VERSION_MANY + RPAREN) | VERSION_MANY))
# ---> 55 _VERSION_SPEC.setParseAction(lambda s, l, t: t._raw_spec or "")
#      56
#      57 VERSION_SPEC = originalTextFor(_VERSION_SPEC)("specifier")
#
# ~\anaconda3\lib\site-packages\pkg_resources\_vendor\pyparsing.py in setParseAction(self, *fns, **kwargs)
#    1282             date_str.parseString("1999/12/31")  # -> [1999, '/', 12, '/', 31]
#    1283         """
# -> 1284         self.parseAction = list(map(_trim_arity, list(fns)))
#    1285         self.callDuringTry = kwargs.get("callDuringTry", False)
#    1286         return self
#
# ~\anaconda3\lib\site-packages\pkg_resources\_vendor\pyparsing.py in _trim_arity(func, maxargs)
#    1064     # IF ANY CODE CHANGES, EVEN JUST COMMENTS OR BLANK LINES, BETWEEN THE NEXT LINE AND
#    1065     # THE CALL TO FUNC INSIDE WRAPPER, LINE_DIFF MUST BE MODIFIED!!!!
# -> 1066     this_line = extract_stack(limit=2)[-1]
#    1067     pa_call_line_synth = (this_line[0], this_line[1]+LINE_DIFF)
#    1068
#
# ~\anaconda3\lib\site-packages\pkg_resources\_vendor\pyparsing.py in extract_stack(limit)
#    1048             # special handling for Python 3.5.0 - extra deep call stack by 1
#    1049             offset = -3 if system_version == (3,5,0) else -2
# -> 1050             frame_summary = traceback.extract_stack(limit=-offset+limit-1)[offset]
#    1051             return [frame_summary[:2]]
#    1052         def extract_tb(tb, limit=0):
#
# ~\anaconda3\lib\traceback.py in extract_stack(f, limit)
#     209     if f is None:
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#     213     return stack
#
# ~\anaconda3\lib\traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     360                 filename, lineno, name, lookup_line=False, locals=f_locals))
#     361         for filename in fnames:
# --> 362             linecache.checkcache(filename)
#     363         # If immediate lookup was desired, trigger lookups now.
#     364         if lookup_lines:
#
# ~\anaconda3\lib\site-packages\IPython\core\compilerop.py in check_linecache_ipython(*args)
#     155     """
#     156     # First call the original checkcache as intended
# --> 157     linecache._checkcache_ori(*args)
#     158     # Then, update back the cache with our data, so that tracebacks related
#     159     # to our compiled codes can be produced.
#
# ~\anaconda3\lib\linecache.py in checkcache(filename)
#      72             continue   # no-op for files loaded via a __loader__
#      73         try:
# ---> 74             stat = os.stat(fullname)
#      75         except OSError:
#      76             del cache[filename]
#
# KeyboardInterrupt:
