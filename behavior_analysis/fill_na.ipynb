# %%
import pandas as pd

df = pd.read_csv (r'Gal_37_father_retreive_trial_1.csv')
df = df.fillna(0)

csvFile = ('Gal_37_father_retreive_trial_1.csv')
df.to_csv(csvFile, index=False)

df
# Out:
#        Unnamed: 0      nose_x      nose_y    nose_p  head_center_x  \
# 0               0  583.483948  231.141174  0.999917     562.352966
# 1               1  583.635620  231.200104  0.999912     562.411499
# 2               2  583.635620  231.200104  0.999912     562.411499
# 3               3  583.635620  231.200104  0.999912     562.411499
# 4               4  583.757019  231.278305  0.999906     562.403442
# ...           ...         ...         ...       ...            ...
# 32378       32378  489.413940  177.604950  0.009721     467.933014
# 32379       32379  489.659729  176.801636  0.007097     469.497162
# 32380       32380  489.659729  176.801636  0.007097     469.497162
# 32381       32381  489.463440  176.707825  0.006755     469.669403
# 32382       32382  489.410309  177.069885  0.007447     469.631226
#
#        head_center_y  head_center_p  ear_left_x  ear_left_y  ear_left_p  ...  \
# 0         230.199463       0.999919  541.951233  216.104523    0.999761  ...
# ...
